# %%
# !pip install summac
# Out:
# Collecting summac
#   Downloading summac-0.0.4-py3-none-any.whl (30 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from summac) (2.1.0+cu121)
# Requirement already satisfied: transformers>=4.24.0 in /usr/local/lib/python3.10/dist-packages (from summac) (4.35.2)
# Requirement already satisfied: nltk>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from summac) (3.8.1)
# Collecting huggingface-hub<=0.17.0 (from summac)
#   Downloading huggingface_hub-0.17.0-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 7.6 MB/s eta 0:00:00
# Collecting sentencepiece (from summac)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.8 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from summac) (3.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<=0.17.0->summac) (3.13.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<=0.17.0->summac) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<=0.17.0->summac) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<=0.17.0->summac) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<=0.17.0->summac) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<=0.17.0->summac) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<=0.17.0->summac) (23.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.6.6->summac) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.6.6->summac) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.6.6->summac) (2023.6.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.24.0->summac) (1.23.5)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.24.0->summac) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.24.0->summac) (0.4.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->summac) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->summac) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->summac) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->summac) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->summac) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<=0.17.0->summac) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<=0.17.0->summac) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<=0.17.0->summac) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<=0.17.0->summac) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->summac) (1.3.0)
# Installing collected packages: sentencepiece, huggingface-hub, summac
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.19.4
#     Uninstalling huggingface-hub-0.19.4:
#       Successfully uninstalled huggingface-hub-0.19.4
# Successfully installed huggingface-hub-0.17.0 sentencepiece-0.1.99 summac-0.0.4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import nltk
nltk.download('punkt') # this is a required dependency for SummaC it seems
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# Test SummaC

# %%
from summac.model_summac import SummaCZS, SummaCConv
# This code is copied from the SummaC github example to start using the metric: https://github.com/tingofurro/summac
model_zs = SummaCZS(granularity="sentence", model_name="vitc", device="cuda") # If you have a GPU: switch to: device="cuda"
model_conv = SummaCConv(models=["vitc"], bins='percentile', granularity="sentence", nli_labels="e", device="cuda", start_file="default", agg="mean")

document = """Scientists are studying Mars to learn about the Red Planet and find landing sites for future missions.
One possible site, known as Arcadia Planitia, is covered instrange sinuous features.
The shapes could be signs that the area is actually made of glaciers, which are large masses of slow-moving ice.
Arcadia Planitia is in Mars' northern lowlands."""

summary1 = "There are strange shape patterns on Arcadia Planitia. The shapes could indicate the area might be made of glaciers. This makes Arcadia Planitia ideal for future missions."
score_zs1 = model_zs.score([document], [summary1])
score_conv1 = model_conv.score([document], [summary1])
print("[Summary 1] SummaCZS Score: %.3f; SummacConv score: %.3f" % (score_zs1["scores"][0], score_conv1["scores"][0])) # [Summary 1] SummaCZS Score: 0.582; SummacConv score: 0.536

summary2 = "There are strange shape patterns on Arcadia Planitia. The shapes could indicate the area might be made of glaciers."
score_zs2 = model_zs.score([document], [summary2])
score_conv2 = model_conv.score([document], [summary2])
print("[Summary 2] SummaCZS Score: %.3f; SummacConv score: %.3f" % (score_zs2["scores"][0], score_conv2["scores"][0])) # [Summary 2] SummaCZS Score: 0.877; SummacConv score: 0.709
# Out:
# <All keys matched successfully>
# Downloading tokenizer_config.json:   0%|          | 0.00/217 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/1.09k [00:00<?, ?B/s]
# Downloading spiece.model:   0%|          | 0.00/760k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/156 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/235M [00:00<?, ?B/s]
# [Summary 1] SummaCZS Score: 0.583; SummacConv score: 0.536
# [Summary 2] SummaCZS Score: 0.877; SummacConv score: 0.709
# /usr/local/lib/python3.10/dist-packages/summac/model_summac.py:298: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:261.)
#   histograms = torch.FloatTensor(histograms).to(self.device)

# %%
model_name = "mistral" # Make sure this matches the name of the predictions filepath

# %%
import pandas as pd

df = pd.read_csv(f"/content/drive/MyDrive/Lang Gen Project/Results/{model_name}_predictions.csv")

documents = df['Input'].tolist()
summaries = df['Prediction'].tolist()

if len(documents) != len(summaries):
        raise ValueError("The lengths of the documents and summaries lists do not match.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-133db40dd14b> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv(f"/content/drive/MyDrive/Lang Gen Project/Results/{model_name}_predictions.csv")
#       4
#       5 documents = df['Input'].tolist()
#
# NameError: name 'model_name' is not defined

# %%
print(documents[31])
# Out:
# During the course of the seven-week trial, the plaintiffs introduced evidence of hundreds of acts committed by the defendants or others acting in concert with PLAN which, the plaintiffs contended, constituted predicate acts under RICO. The plaintiffs alleged, and at trial the jury found, that PLAN was an “organization or enterprise” for purposes of RICO liability. Participants in the protest missions engage in a substantial amount of protected speech, including efforts to persuade clinic patients not to have abortions and to persuade clinic doctors and staff to quit performing abortions. A jury found for the plaintiffs and awarded damages to the two named clinics, and the district court issued a permanent nationwide injunction prohibiting the defendants from conducting blockades, trespassing, damaging property, or committing acts of violence at the class clinics. All of the defendants were among the organizers of the Pro-Life Action Network (PLAN), which is a loose national organization of groups that engage in protest missions and other aggressive anti-abortion tactics. The defendants have appealed a wide range of issues relating to the conduct of the trial and the issuance of the injunction. The Supreme Court granted certiorari on the limited question whether RICO requires proof that either the racketeering enterprise or the alleged predicate acts were motivated by an economic purpose. Thereafter, we remanded the case to the district court for trial of the plaintiffs’ RICO claims. ® In several instances, protesters entered clinics and destroyed medical equipment. § 1952, and conspiracy to violate these laws. In interpreting the remedial provisions of the RICO statute, our inquiry begins with the statute’s text, and, if the text is unambiguous, it ends there as well. II Initially, we must consider the defendants’ contention that RICO does not permit private plaintiffs to seek injunctive relief. The jury awarded damages to both clinics; once the damages were trebled, as RICO requires, the awards totaled over $163,000 to Summit Women’s Health Organization and over $94,000 to Delaware Women’s Health Organization. The only court of appeals to have addressed this issue directly, the Ninth Circuit, concluded in 1986 that private plaintiffs cannot seek injunctions under RICO, relying largely on the court’s reading of the statute’s legislative history. Section 1964(b), in the defendants’ view, allows the Attorney General to institute RICO proceedings and authorizes the government to seek not only the relief described in that subsection, but also the relief described in § 1964(a). Although no one doubts that permanent injunctions are also available to the government, the government’s ability to seek permanent, as opposed to interim, equitable remedies comes from the general grant of authority for district courts to enter injunctions found in § 1964(a), not from anything in § 1964(b). Relying on Wollersheim, they argue that § 1964(a) is purely a jurisdictional provision authorizing the district court to hear RICO claims and to grant injunctions to parties authorized by other provisions of the law to seek that form of relief. Section 1964(b) makes it clear that the statute is to be publicly enforced by the Attorney General and it specifies additional remedies, all in the nature of interim relief, that the government may seek. Given that the government’s authority to seek injunctions comes from the combination of the grant of a right of action to the Attorney General in § 1964(b) and the grant of district court authority to enter injunctions in § 1964(a), we see no reason not to conclude, by parity of reasoning, that private parties can also seek injunctions under the combination of grants in §§ 1964(a) and (c). In addition, we cannot agree with the defendants’ contention that § 1964(a) is a purely “jurisdictional” statute, despite the Ninth Circuit’s characterization of it in that way in Imagineering, Inc. v. Kiewit Pac. The statute at  ...

# %%
print(summaries[31])
# Out:
#  and the defendants, it in the district court’s relief in the defendants. the district court’s relief, the defendants, the plaint, the defendants, the district court, the court’s relief, the plaint. In addition, the relief, the court, the relief, the relief, the relief, the defendants in the district court, the relief, the relief, the relief, the defendants, the district court. The relief, the relief. In the relief. The district court, the relief, the relief. This district court. The relief. 1
# In the relief. In this case, the relief, you must-the district court, the relief. District Court. In this relief, the relief. The relief, the relief, the relief, the relief, the relief, the court, the district court.
# As relief.
# relay relief, you.
# The relief, the court, the relief. The relief. In the relief. District Court.
# The relief.
# DEN relief.
# on the district court. The district.
# 10Ъ relief, the relief, and relief, you are related.
# .
# (d.
# ... the following lit knowing. In thisrel (specific relief.
# հ _ nobody.
# You.
# rels court.
# under the district.
# lit.
# rel sierpéqu nobody.
# sim {\ nobody.
# Defense, as follows.
#  hopefully. D Einzeln.Ə, nobody.
# You., the defend, and everybody.
# ☉ the court.
#  nobody.
# det the pla Einzeln.
# pass theft.
# factor and \ Begriffe ( nobody.
#  Begriffe, nobody.
#  everybody.
#  sierp.
#  everybody. ( sierp everybody. _ everybody. The kwiet Unterscheidung nobody ( sierp everybody everybody ( kwiet surely these nobody hopefully nobody everybody everybody everybody everyone hopefully nobody surely everybody nobody everybody everybody nobody surely nobody nobodyἱϊ nobody everybody everybody Unterscheidung nobody everyone (его Unterscheidung sierp nobody nobody hopefully Unterscheidung Unterscheidung everyone. Theἱ Unterscheidung nobodyἱ Unterscheidung everybody everybody Unterscheidung nobody nobody obviously everybody nobody nobody nobody sierp nobody nobody everybody Hinweis kwiet sierp sierp Einzeln nobody nobody everybody everybody nobody hopefully nobody nobody Bildern << everybody Unterscheidung everybody everybody nobody Unterscheidung Einzeln everybody nobody everybody nobody Einzeln everybodyϊἱ Einzeln everybody Unterscheidungἱ knowing everybody everybody nobody hopefullyϊ nobody nobody everybody Begriffe nobody Unterscheidung everybody Unterscheidung everybody everybody Unterscheidung anybody nobody everybodyἱ nobody nobody everybody nobody surely nobody surely nobody hopefully nobody everyone zwar everyone zwar everybody Hinweis nobody everybody nobody nobody everyone Hinweis everyone nobody. kwiet everybody, nobody obviously everybody nobody nobody Einzeln everybody everybody nobody everybody surely everybody nobody everybody kwiet everybody everybody Einzeln nobody nobody nobody everybody nobody and nobody nobody nobodypareseparseeessysidesite nobodyess nobody nobody nobody and everybody nobody. everybody zwarese nobody, nobody nobody, ultimately nobody (plasetmart nobody nobody hopefully everybody nobody everybody. nobody everybody everybody everybody everybody Bildern everybody nobody everybody Einzeln everybody everybody everyone nobody everybody everybody nobody everybody everybody everybody Unterscheidung nobody nobody nobody everybody everybody everybody everyone everyone everybody everybody nobody nobody nobody nobody stycz everybody everybody nobody nobody nobody knowing styczser nobody Einzeln everybodyish
# mior everybody nobody nobody everybody nobody. everybody nobody everyone everyone nobody hopefully nobody nobody nobody _state (state _factor knowing everybody <<scoite _ nobody.coysidescope andek case »understyscor-paress nobody everybodystysyllssophowedyll-contese (circows nobody as everybodyese nobody everyone everyone. <<supier acts <<rei nobody everyone nobody nobody everybody (use hopefully everyoness everybody everybody (underst everybodyss nobody everybody nobody nobodyssess_br>car nobody everybody>state everybody everybody everyone everybody, _the _par everybodyssess\state-underessessess (you _(brA <<essselessss _under_related <<state, <<co_under the <<under, _undersuit Begriffe\howsoelfessidesidesidesidesideessít everyone Begriffe nobody everybody nobody nobody everyone _sup the _wostream Begriffesimstreamessslscsvessegssesesesaw_dess
# coess
# co>signess
# d>dessite-underscide-sskstreamll
# [s
# the (s.ll (s (s_understsksitesgshotstreamsvstreamsvsg.sg.ek_under.s.site_sscstreamstides tollstsvsosvskstskste to _sol ( 1.st (1 (its, 1st (s (s (s (s (s (s (d (s (dys (dsc (d_d, _d, _dstreamshotswstream,swsolskysachswswll, _available _sol_fi>s _sysysststreamthsd _solnessessite _>>fi (<<sk to the to its_s, to the to the to the to
# th to the to the to _toys

# %%
test_score = model_conv.score([documents[2]], [summaries[2]])
print(test_score)
# Out:
# {'scores': [0.4756242632865906]}

# %%
total_score = 0
scores = []
num = 0

for document, summary in zip(documents, summaries):
  print(f"Calculate SummaC Conv score for summary number {num+1}")
  num += 1
  if pd.isna(summary):
    summary = "Null"
  score = model_conv.score([document], [summary])
  {'Document': document, 'Summary': summary, 'Score': score}
  scores.append({'Document': document, 'Summary': summary, 'Score': score['scores'][0]})
  total_score += score['scores'][0]

results_df = pd.DataFrame(scores)
results_df.to_csv(f'/content/drive/MyDrive/Lang Gen Project/Metrics/{model_name}_summac_results.csv', index=False)
# Calculate and write average score
average_score = total_score / len(scores)
with open(f'/content/drive/MyDrive/Lang Gen Project/Metrics/{model_name}_average_summac.txt', 'w') as file:
    file.write(f"Average Score: {average_score}\n")
# Out:
# Calculate SummaC Conv score for summary number 1
# Calculate SummaC Conv score for summary number 2
# Calculate SummaC Conv score for summary number 3
# Calculate SummaC Conv score for summary number 4
# Calculate SummaC Conv score for summary number 5
# Calculate SummaC Conv score for summary number 6
# Calculate SummaC Conv score for summary number 7
# Calculate SummaC Conv score for summary number 8
# Calculate SummaC Conv score for summary number 9
# Calculate SummaC Conv score for summary number 10
# Calculate SummaC Conv score for summary number 11
# Calculate SummaC Conv score for summary number 12
# Calculate SummaC Conv score for summary number 13
# Calculate SummaC Conv score for summary number 14
# Calculate SummaC Conv score for summary number 15
# Calculate SummaC Conv score for summary number 16
# Calculate SummaC Conv score for summary number 17
# Calculate SummaC Conv score for summary number 18
# Calculate SummaC Conv score for summary number 19
# Calculate SummaC Conv score for summary number 20
# Calculate SummaC Conv score for summary number 21
# Calculate SummaC Conv score for summary number 22
# Calculate SummaC Conv score for summary number 23
# Calculate SummaC Conv score for summary number 24
# Calculate SummaC Conv score for summary number 25
# Calculate SummaC Conv score for summary number 26
# Calculate SummaC Conv score for summary number 27
# Calculate SummaC Conv score for summary number 28
# Calculate SummaC Conv score for summary number 29
# Calculate SummaC Conv score for summary number 30
# Calculate SummaC Conv score for summary number 31
# Calculate SummaC Conv score for summary number 32
# Calculate SummaC Conv score for summary number 33
# Calculate SummaC Conv score for summary number 34
# Calculate SummaC Conv score for summary number 35
# Calculate SummaC Conv score for summary number 36
# Calculate SummaC Conv score for summary number 37
# Calculate SummaC Conv score for summary number 38
# Calculate SummaC Conv score for summary number 39
# Calculate SummaC Conv score for summary number 40
# Calculate SummaC Conv score for summary number 41
# Calculate SummaC Conv score for summary number 42
# Calculate SummaC Conv score for summary number 43
# Calculate SummaC Conv score for summary number 44
# Calculate SummaC Conv score for summary number 45
# Calculate SummaC Conv score for summary number 46
# Calculate SummaC Conv score for summary number 47
# Calculate SummaC Conv score for summary number 48
# Calculate SummaC Conv score for summary number 49
# Calculate SummaC Conv score for summary number 50
# Calculate SummaC Conv score for summary number 51
# Calculate SummaC Conv score for summary number 52
# Calculate SummaC Conv score for summary number 53
# Calculate SummaC Conv score for summary number 54
# Calculate SummaC Conv score for summary number 55
# Calculate SummaC Conv score for summary number 56
# Calculate SummaC Conv score for summary number 57
# Calculate SummaC Conv score for summary number 58
# Calculate SummaC Conv score for summary number 59
# Calculate SummaC Conv score for summary number 60
# Calculate SummaC Conv score for summary number 61
# Calculate SummaC Conv score for summary number 62
# Calculate SummaC Conv score for summary number 63
# Calculate SummaC Conv score for summary number 64
# Calculate SummaC Conv score for summary number 65
# Calculate SummaC Conv score for summary number 66
# Calculate SummaC Conv score for summary number 67
# Calculate SummaC Conv score for summary number 68
# Calculate SummaC Conv score for summary number 69
# Calculate SummaC Conv score for summary number 70
# Calculate SummaC Conv score for summary number 71
# Calculate SummaC Conv score for summary number 72
# Calculate SummaC Conv score for summary number 73
# Calculate SummaC Conv score for summary number 74
# Calculate SummaC Conv score for summary number 75
# Calculate SummaC Conv score for summary number 76
# Calculate SummaC Conv score for summary number 77
# Calculate SummaC Conv score for summary number 78
# Calculate SummaC Conv score for summary number 79
# Calculate SummaC Conv score for summary number 80
# Calculate SummaC Conv score for summary number 81
# Calculate SummaC Conv score for summary number 82
# Calculate SummaC Conv score for summary number 83
# Calculate SummaC Conv score for summary number 84
# Calculate SummaC Conv score for summary number 85
# Calculate SummaC Conv score for summary number 86
# Calculate SummaC Conv score for summary number 87
# Calculate SummaC Conv score for summary number 88
# Calculate SummaC Conv score for summary number 89
# Calculate SummaC Conv score for summary number 90
# Calculate SummaC Conv score for summary number 91
# Calculate SummaC Conv score for summary number 92
# Calculate SummaC Conv score for summary number 93
# Calculate SummaC Conv score for summary number 94
# Calculate SummaC Conv score for summary number 95
# Calculate SummaC Conv score for summary number 96
# Calculate SummaC Conv score for summary number 97
# Calculate SummaC Conv score for summary number 98
# Calculate SummaC Conv score for summary number 99
# Calculate SummaC Conv score for summary number 100
# Calculate SummaC Conv score for summary number 101
# Calculate SummaC Conv score for summary number 102
# Calculate SummaC Conv score for summary number 103
# Calculate SummaC Conv score for summary number 104
# Calculate SummaC Conv score for summary number 105
# Calculate SummaC Conv score for summary number 106
# Calculate SummaC Conv score for summary number 107
# Calculate SummaC Conv score for summary number 108
# Calculate SummaC Conv score for summary number 109
# Calculate SummaC Conv score for summary number 110
# Calculate SummaC Conv score for summary number 111
# Calculate SummaC Conv score for summary number 112
# Calculate SummaC Conv score for summary number 113
# Calculate SummaC Conv score for summary number 114
# Calculate SummaC Conv score for summary number 115
# Calculate SummaC Conv score for summary number 116
# Calculate SummaC Conv score for summary number 117
# Calculate SummaC Conv score for summary number 118
# Calculate SummaC Conv score for summary number 119
# Calculate SummaC Conv score for summary number 120
# Calculate SummaC Conv score for summary number 121
# Calculate SummaC Conv score for summary number 122
# Calculate SummaC Conv score for summary number 123
# Calculate SummaC Conv score for summary number 124
# Calculate SummaC Conv score for summary number 125
# Calculate SummaC Conv score for summary number 126
# Calculate SummaC Conv score for summary number 127
# Calculate SummaC Conv score for summary number 128
# Calculate SummaC Conv score for summary number 129
# Calculate SummaC Conv score for summary number 130
# Calculate SummaC Conv score for summary number 131
# Calculate SummaC Conv score for summary number 132
# Calculate SummaC Conv score for summary number 133
# Calculate SummaC Conv score for summary number 134
# Calculate SummaC Conv score for summary number 135
# Calculate SummaC Conv score for summary number 136
# Calculate SummaC Conv score for summary number 137
# Calculate SummaC Conv score for summary number 138
# Calculate SummaC Conv score for summary number 139
# Calculate SummaC Conv score for summary number 140
# Calculate SummaC Conv score for summary number 141
# Calculate SummaC Conv score for summary number 142
# Calculate SummaC Conv score for summary number 143
# Calculate SummaC Conv score for summary number 144
# Calculate SummaC Conv score for summary number 145
# Calculate SummaC Conv score for summary number 146
# Calculate SummaC Conv score for summary number 147
# Calculate SummaC Conv score for summary number 148
# Calculate SummaC Conv score for summary number 149
# Calculate SummaC Conv score for summary number 150
# Calculate SummaC Conv score for summary number 151
# Calculate SummaC Conv score for summary number 152
# Calculate SummaC Conv score for summary number 153
# Calculate SummaC Conv score for summary number 154
# Calculate SummaC Conv score for summary number 155
# Calculate SummaC Conv score for summary number 156
# Calculate SummaC Conv score for summary number 157
# Calculate SummaC Conv score for summary number 158
# Calculate SummaC Conv score for summary number 159
# Calculate SummaC Conv score for summary number 160
# Calculate SummaC Conv score for summary number 161
# Calculate SummaC Conv score for summary number 162
# Calculate SummaC Conv score for summary number 163
# Calculate SummaC Conv score for summary number 164
# Calculate SummaC Conv score for summary number 165
# Calculate SummaC Conv score for summary number 166
# Calculate SummaC Conv score for summary number 167
# Calculate SummaC Conv score for summary number 168
# Calculate SummaC Conv score for summary number 169
# Calculate SummaC Conv score for summary number 170
# Calculate SummaC Conv score for summary number 171
# Calculate SummaC Conv score for summary number 172
# Calculate SummaC Conv score for summary number 173
# Calculate SummaC Conv score for summary number 174
# Calculate SummaC Conv score for summary number 175
# Calculate SummaC Conv score for summary number 176
# Calculate SummaC Conv score for summary number 177
# Calculate SummaC Conv score for summary number 178
# Calculate SummaC Conv score for summary number 179
# Calculate SummaC Conv score for summary number 180
# Calculate SummaC Conv score for summary number 181
# Calculate SummaC Conv score for summary number 182
# Calculate SummaC Conv score for summary number 183
# Calculate SummaC Conv score for summary number 184
# Calculate SummaC Conv score for summary number 185
# Calculate SummaC Conv score for summary number 186
# Calculate SummaC Conv score for summary number 187
# Calculate SummaC Conv score for summary number 188
# Calculate SummaC Conv score for summary number 189
# Calculate SummaC Conv score for summary number 190
# Calculate SummaC Conv score for summary number 191
# Calculate SummaC Conv score for summary number 192
# Calculate SummaC Conv score for summary number 193
# Calculate SummaC Conv score for summary number 194
# Calculate SummaC Conv score for summary number 195
# Calculate SummaC Conv score for summary number 196
# Calculate SummaC Conv score for summary number 197
# Calculate SummaC Conv score for summary number 198
# Calculate SummaC Conv score for summary number 199
# Calculate SummaC Conv score for summary number 200
# Calculate SummaC Conv score for summary number 201
# Calculate SummaC Conv score for summary number 202
# Calculate SummaC Conv score for summary number 203
# Calculate SummaC Conv score for summary number 204
# Calculate SummaC Conv score for summary number 205
# Calculate SummaC Conv score for summary number 206
# Calculate SummaC Conv score for summary number 207
# Calculate SummaC Conv score for summary number 208
# Calculate SummaC Conv score for summary number 209
# Calculate SummaC Conv score for summary number 210
# Calculate SummaC Conv score for summary number 211
# Calculate SummaC Conv score for summary number 212
# Calculate SummaC Conv score for summary number 213
# Calculate SummaC Conv score for summary number 214
# Calculate SummaC Conv score for summary number 215
# Calculate SummaC Conv score for summary number 216
# Calculate SummaC Conv score for summary number 217
# Calculate SummaC Conv score for summary number 218
# Calculate SummaC Conv score for summary number 219
# Calculate SummaC Conv score for summary number 220
# Calculate SummaC Conv score for summary number 221
# Calculate SummaC Conv score for summary number 222
# Calculate SummaC Conv score for summary number 223
# Calculate SummaC Conv score for summary number 224
# Calculate SummaC Conv score for summary number 225
# Calculate SummaC Conv score for summary number 226
# Calculate SummaC Conv score for summary number 227
# Calculate SummaC Conv score for summary number 228
# Calculate SummaC Conv score for summary number 229
# Calculate SummaC Conv score for summary number 230
# Calculate SummaC Conv score for summary number 231
# Calculate SummaC Conv score for summary number 232
# Calculate SummaC Conv score for summary number 233
# Calculate SummaC Conv score for summary number 234
# Calculate SummaC Conv score for summary number 235
# Calculate SummaC Conv score for summary number 236
# Calculate SummaC Conv score for summary number 237
# Calculate SummaC Conv score for summary number 238
# Calculate SummaC Conv score for summary number 239
# Calculate SummaC Conv score for summary number 240
# Calculate SummaC Conv score for summary number 241
# Calculate SummaC Conv score for summary number 242
# Calculate SummaC Conv score for summary number 243
# Calculate SummaC Conv score for summary number 244
# Calculate SummaC Conv score for summary number 245
# Calculate SummaC Conv score for summary number 246
# Calculate SummaC Conv score for summary number 247
# Calculate SummaC Conv score for summary number 248
# Calculate SummaC Conv score for summary number 249
# Calculate SummaC Conv score for summary number 250
# Calculate SummaC Conv score for summary number 251
# Calculate SummaC Conv score for summary number 252
# Calculate SummaC Conv score for summary number 253
# Calculate SummaC Conv score for summary number 254
# Calculate SummaC Conv score for summary number 255
# Calculate SummaC Conv score for summary number 256
# Calculate SummaC Conv score for summary number 257
# Calculate SummaC Conv score for summary number 258
# Calculate SummaC Conv score for summary number 259
# Calculate SummaC Conv score for summary number 260
# Calculate SummaC Conv score for summary number 261
# Calculate SummaC Conv score for summary number 262
# Calculate SummaC Conv score for summary number 263
# Calculate SummaC Conv score for summary number 264
# Calculate SummaC Conv score for summary number 265
# Calculate SummaC Conv score for summary number 266
# Calculate SummaC Conv score for summary number 267
# Calculate SummaC Conv score for summary number 268
# Calculate SummaC Conv score for summary number 269
# Calculate SummaC Conv score for summary number 270
# Calculate SummaC Conv score for summary number 271
# Calculate SummaC Conv score for summary number 272
# Calculate SummaC Conv score for summary number 273
# Calculate SummaC Conv score for summary number 274
# Calculate SummaC Conv score for summary number 275
# Calculate SummaC Conv score for summary number 276
# Calculate SummaC Conv score for summary number 277
# Calculate SummaC Conv score for summary number 278
# Calculate SummaC Conv score for summary number 279
# Calculate SummaC Conv score for summary number 280
# Calculate SummaC Conv score for summary number 281
# Calculate SummaC Conv score for summary number 282
# Calculate SummaC Conv score for summary number 283
# Calculate SummaC Conv score for summary number 284
# Calculate SummaC Conv score for summary number 285
# Calculate SummaC Conv score for summary number 286
# Calculate SummaC Conv score for summary number 287
# Calculate SummaC Conv score for summary number 288
# Calculate SummaC Conv score for summary number 289
# Calculate SummaC Conv score for summary number 290
# Calculate SummaC Conv score for summary number 291
# Calculate SummaC Conv score for summary number 292
# Calculate SummaC Conv score for summary number 293
# Calculate SummaC Conv score for summary number 294
# Calculate SummaC Conv score for summary number 295
# Calculate SummaC Conv score for summary number 296
# Calculate SummaC Conv score for summary number 297
# Calculate SummaC Conv score for summary number 298
# Calculate SummaC Conv score for summary number 299
# Calculate SummaC Conv score for summary number 300
# Calculate SummaC Conv score for summary number 301
# Calculate SummaC Conv score for summary number 302
# Calculate SummaC Conv score for summary number 303
# Calculate SummaC Conv score for summary number 304
# Calculate SummaC Conv score for summary number 305
# Calculate SummaC Conv score for summary number 306
# Calculate SummaC Conv score for summary number 307
# Calculate SummaC Conv score for summary number 308
# Calculate SummaC Conv score for summary number 309
# Calculate SummaC Conv score for summary number 310
# Calculate SummaC Conv score for summary number 311
# Calculate SummaC Conv score for summary number 312
# Calculate SummaC Conv score for summary number 313
# Calculate SummaC Conv score for summary number 314
# Calculate SummaC Conv score for summary number 315
# Calculate SummaC Conv score for summary number 316
# Calculate SummaC Conv score for summary number 317
# Calculate SummaC Conv score for summary number 318
# Calculate SummaC Conv score for summary number 319
# Calculate SummaC Conv score for summary number 320
# Calculate SummaC Conv score for summary number 321
# Calculate SummaC Conv score for summary number 322
# Calculate SummaC Conv score for summary number 323
# Calculate SummaC Conv score for summary number 324
# Calculate SummaC Conv score for summary number 325
# Calculate SummaC Conv score for summary number 326
# Calculate SummaC Conv score for summary number 327
# Calculate SummaC Conv score for summary number 328
# Calculate SummaC Conv score for summary number 329
# Calculate SummaC Conv score for summary number 330
# Calculate SummaC Conv score for summary number 331
# Calculate SummaC Conv score for summary number 332
# Calculate SummaC Conv score for summary number 333
# Calculate SummaC Conv score for summary number 334
# Calculate SummaC Conv score for summary number 335
# Calculate SummaC Conv score for summary number 336
# Calculate SummaC Conv score for summary number 337
# Calculate SummaC Conv score for summary number 338
# Calculate SummaC Conv score for summary number 339
# Calculate SummaC Conv score for summary number 340
# Calculate SummaC Conv score for summary number 341
# Calculate SummaC Conv score for summary number 342
# Calculate SummaC Conv score for summary number 343
# Calculate SummaC Conv score for summary number 344
# Calculate SummaC Conv score for summary number 345
# Calculate SummaC Conv score for summary number 346
# Calculate SummaC Conv score for summary number 347
# Calculate SummaC Conv score for summary number 348
# Calculate SummaC Conv score for summary number 349
# Calculate SummaC Conv score for summary number 350
# Calculate SummaC Conv score for summary number 351
# Calculate SummaC Conv score for summary number 352
# Calculate SummaC Conv score for summary number 353
# Calculate SummaC Conv score for summary number 354
# Calculate SummaC Conv score for summary number 355
# Calculate SummaC Conv score for summary number 356
# Calculate SummaC Conv score for summary number 357
# Calculate SummaC Conv score for summary number 358
# Calculate SummaC Conv score for summary number 359
# Calculate SummaC Conv score for summary number 360
# Calculate SummaC Conv score for summary number 361
# Calculate SummaC Conv score for summary number 362
# Calculate SummaC Conv score for summary number 363
# Calculate SummaC Conv score for summary number 364
# Calculate SummaC Conv score for summary number 365
# Calculate SummaC Conv score for summary number 366
# Calculate SummaC Conv score for summary number 367
# Calculate SummaC Conv score for summary number 368
# Calculate SummaC Conv score for summary number 369
# Calculate SummaC Conv score for summary number 370
# Calculate SummaC Conv score for summary number 371
# Calculate SummaC Conv score for summary number 372
# Calculate SummaC Conv score for summary number 373
# Calculate SummaC Conv score for summary number 374
# Calculate SummaC Conv score for summary number 375
# Calculate SummaC Conv score for summary number 376
# Calculate SummaC Conv score for summary number 377
# Calculate SummaC Conv score for summary number 378
# Calculate SummaC Conv score for summary number 379
# Calculate SummaC Conv score for summary number 380
# Calculate SummaC Conv score for summary number 381
# Calculate SummaC Conv score for summary number 382
# Calculate SummaC Conv score for summary number 383
# Calculate SummaC Conv score for summary number 384
# Calculate SummaC Conv score for summary number 385
# Calculate SummaC Conv score for summary number 386
# Calculate SummaC Conv score for summary number 387
# Calculate SummaC Conv score for summary number 388
# Calculate SummaC Conv score for summary number 389
# Calculate SummaC Conv score for summary number 390
# Calculate SummaC Conv score for summary number 391
# Calculate SummaC Conv score for summary number 392
# Calculate SummaC Conv score for summary number 393
# Calculate SummaC Conv score for summary number 394
# Calculate SummaC Conv score for summary number 395
# Calculate SummaC Conv score for summary number 396
# Calculate SummaC Conv score for summary number 397
# Calculate SummaC Conv score for summary number 398
# Calculate SummaC Conv score for summary number 399
# Calculate SummaC Conv score for summary number 400
# Calculate SummaC Conv score for summary number 401
# Calculate SummaC Conv score for summary number 402
# Calculate SummaC Conv score for summary number 403
# Calculate SummaC Conv score for summary number 404
# Calculate SummaC Conv score for summary number 405
# Calculate SummaC Conv score for summary number 406
# Calculate SummaC Conv score for summary number 407
# Calculate SummaC Conv score for summary number 408
# Calculate SummaC Conv score for summary number 409
# Calculate SummaC Conv score for summary number 410
# Calculate SummaC Conv score for summary number 411
# Calculate SummaC Conv score for summary number 412
# Calculate SummaC Conv score for summary number 413
# Calculate SummaC Conv score for summary number 414
# Calculate SummaC Conv score for summary number 415
# Calculate SummaC Conv score for summary number 416
# Calculate SummaC Conv score for summary number 417
# Calculate SummaC Conv score for summary number 418
# Calculate SummaC Conv score for summary number 419
# Calculate SummaC Conv score for summary number 420
# Calculate SummaC Conv score for summary number 421
# Calculate SummaC Conv score for summary number 422
# Calculate SummaC Conv score for summary number 423
# Calculate SummaC Conv score for summary number 424
# Calculate SummaC Conv score for summary number 425
# Calculate SummaC Conv score for summary number 426
# Calculate SummaC Conv score for summary number 427
# Calculate SummaC Conv score for summary number 428
# Calculate SummaC Conv score for summary number 429
# Calculate SummaC Conv score for summary number 430
# Calculate SummaC Conv score for summary number 431
# Calculate SummaC Conv score for summary number 432
# Calculate SummaC Conv score for summary number 433
# Calculate SummaC Conv score for summary number 434
# Calculate SummaC Conv score for summary number 435
# Calculate SummaC Conv score for summary number 436
# Calculate SummaC Conv score for summary number 437
# Calculate SummaC Conv score for summary number 438
# Calculate SummaC Conv score for summary number 439
# Calculate SummaC Conv score for summary number 440
# Calculate SummaC Conv score for summary number 441
# Calculate SummaC Conv score for summary number 442
# Calculate SummaC Conv score for summary number 443
# Calculate SummaC Conv score for summary number 444
# Calculate SummaC Conv score for summary number 445
# Calculate SummaC Conv score for summary number 446
# Calculate SummaC Conv score for summary number 447
# Calculate SummaC Conv score for summary number 448
# Calculate SummaC Conv score for summary number 449
# Calculate SummaC Conv score for summary number 450
# Calculate SummaC Conv score for summary number 451
# Calculate SummaC Conv score for summary number 452
# Calculate SummaC Conv score for summary number 453
# Calculate SummaC Conv score for summary number 454
# Calculate SummaC Conv score for summary number 455
# Calculate SummaC Conv score for summary number 456
# Calculate SummaC Conv score for summary number 457
# Calculate SummaC Conv score for summary number 458
# Calculate SummaC Conv score for summary number 459
# Calculate SummaC Conv score for summary number 460
# Calculate SummaC Conv score for summary number 461
# Calculate SummaC Conv score for summary number 462
# Calculate SummaC Conv score for summary number 463
# Calculate SummaC Conv score for summary number 464
# Calculate SummaC Conv score for summary number 465
# Calculate SummaC Conv score for summary number 466
# Calculate SummaC Conv score for summary number 467
# Calculate SummaC Conv score for summary number 468
# Calculate SummaC Conv score for summary number 469
# Calculate SummaC Conv score for summary number 470
# Calculate SummaC Conv score for summary number 471
# Calculate SummaC Conv score for summary number 472
# Calculate SummaC Conv score for summary number 473
# Calculate SummaC Conv score for summary number 474
# Calculate SummaC Conv score for summary number 475
# Calculate SummaC Conv score for summary number 476
# Calculate SummaC Conv score for summary number 477
# Calculate SummaC Conv score for summary number 478
# Calculate SummaC Conv score for summary number 479
# Calculate SummaC Conv score for summary number 480
# Calculate SummaC Conv score for summary number 481
# Calculate SummaC Conv score for summary number 482
# Calculate SummaC Conv score for summary number 483
# Calculate SummaC Conv score for summary number 484
# Calculate SummaC Conv score for summary number 485
# Calculate SummaC Conv score for summary number 486
# Calculate SummaC Conv score for summary number 487
# Calculate SummaC Conv score for summary number 488
# Calculate SummaC Conv score for summary number 489
# Calculate SummaC Conv score for summary number 490
# Calculate SummaC Conv score for summary number 491
# Calculate SummaC Conv score for summary number 492
# Calculate SummaC Conv score for summary number 493
# Calculate SummaC Conv score for summary number 494
# Calculate SummaC Conv score for summary number 495
# Calculate SummaC Conv score for summary number 496
# Calculate SummaC Conv score for summary number 497
# Calculate SummaC Conv score for summary number 498
# Calculate SummaC Conv score for summary number 499
# Calculate SummaC Conv score for summary number 500
# Calculate SummaC Conv score for summary number 501
# Calculate SummaC Conv score for summary number 502
# Calculate SummaC Conv score for summary number 503
# Calculate SummaC Conv score for summary number 504
# Calculate SummaC Conv score for summary number 505
# Calculate SummaC Conv score for summary number 506
# Calculate SummaC Conv score for summary number 507
# Calculate SummaC Conv score for summary number 508
# Calculate SummaC Conv score for summary number 509
# Calculate SummaC Conv score for summary number 510
# Calculate SummaC Conv score for summary number 511
# Calculate SummaC Conv score for summary number 512
# Calculate SummaC Conv score for summary number 513
# Calculate SummaC Conv score for summary number 514
# Calculate SummaC Conv score for summary number 515
# Calculate SummaC Conv score for summary number 516
# Calculate SummaC Conv score for summary number 517
# Calculate SummaC Conv score for summary number 518
# Calculate SummaC Conv score for summary number 519
# Calculate SummaC Conv score for summary number 520
# Calculate SummaC Conv score for summary number 521
# Calculate SummaC Conv score for summary number 522
# Calculate SummaC Conv score for summary number 523
# Calculate SummaC Conv score for summary number 524
# Calculate SummaC Conv score for summary number 525
# Calculate SummaC Conv score for summary number 526
# Calculate SummaC Conv score for summary number 527
# Calculate SummaC Conv score for summary number 528
# Calculate SummaC Conv score for summary number 529
# Calculate SummaC Conv score for summary number 530
# Calculate SummaC Conv score for summary number 531
# Calculate SummaC Conv score for summary number 532
# Calculate SummaC Conv score for summary number 533
# Calculate SummaC Conv score for summary number 534
# Calculate SummaC Conv score for summary number 535
# Calculate SummaC Conv score for summary number 536
# Calculate SummaC Conv score for summary number 537
# Calculate SummaC Conv score for summary number 538
# Calculate SummaC Conv score for summary number 539
# Calculate SummaC Conv score for summary number 540
# Calculate SummaC Conv score for summary number 541
# Calculate SummaC Conv score for summary number 542
# Calculate SummaC Conv score for summary number 543
# Calculate SummaC Conv score for summary number 544
# Calculate SummaC Conv score for summary number 545
# Calculate SummaC Conv score for summary number 546
# Calculate SummaC Conv score for summary number 547
# Calculate SummaC Conv score for summary number 548
# Calculate SummaC Conv score for summary number 549
# Calculate SummaC Conv score for summary number 550
# Calculate SummaC Conv score for summary number 551
# Calculate SummaC Conv score for summary number 552
# Calculate SummaC Conv score for summary number 553
# Calculate SummaC Conv score for summary number 554
# Calculate SummaC Conv score for summary number 555
# Calculate SummaC Conv score for summary number 556
# Calculate SummaC Conv score for summary number 557
# Calculate SummaC Conv score for summary number 558
# Calculate SummaC Conv score for summary number 559
# Calculate SummaC Conv score for summary number 560
# Calculate SummaC Conv score for summary number 561
# Calculate SummaC Conv score for summary number 562
# Calculate SummaC Conv score for summary number 563
# Calculate SummaC Conv score for summary number 564
# Calculate SummaC Conv score for summary number 565
# Calculate SummaC Conv score for summary number 566
# Calculate SummaC Conv score for summary number 567
# Calculate SummaC Conv score for summary number 568
# Calculate SummaC Conv score for summary number 569
# Calculate SummaC Conv score for summary number 570
# Calculate SummaC Conv score for summary number 571
# Calculate SummaC Conv score for summary number 572
# Calculate SummaC Conv score for summary number 573
# Calculate SummaC Conv score for summary number 574
# Calculate SummaC Conv score for summary number 575
# Calculate SummaC Conv score for summary number 576
# Calculate SummaC Conv score for summary number 577
# Calculate SummaC Conv score for summary number 578
# Calculate SummaC Conv score for summary number 579
# Calculate SummaC Conv score for summary number 580
# Calculate SummaC Conv score for summary number 581
# Calculate SummaC Conv score for summary number 582
# Calculate SummaC Conv score for summary number 583
# Calculate SummaC Conv score for summary number 584
# Calculate SummaC Conv score for summary number 585
# Calculate SummaC Conv score for summary number 586
# Calculate SummaC Conv score for summary number 587
# Calculate SummaC Conv score for summary number 588
# Calculate SummaC Conv score for summary number 589
# Calculate SummaC Conv score for summary number 590
# Calculate SummaC Conv score for summary number 591
# Calculate SummaC Conv score for summary number 592
# Calculate SummaC Conv score for summary number 593
# Calculate SummaC Conv score for summary number 594
# Calculate SummaC Conv score for summary number 595
# Calculate SummaC Conv score for summary number 596
# Calculate SummaC Conv score for summary number 597
# Calculate SummaC Conv score for summary number 598
# Calculate SummaC Conv score for summary number 599
# Calculate SummaC Conv score for summary number 600
# Calculate SummaC Conv score for summary number 601
# Calculate SummaC Conv score for summary number 602
# Calculate SummaC Conv score for summary number 603
# Calculate SummaC Conv score for summary number 604
# Calculate SummaC Conv score for summary number 605
# Calculate SummaC Conv score for summary number 606
# Calculate SummaC Conv score for summary number 607
# Calculate SummaC Conv score for summary number 608
# Calculate SummaC Conv score for summary number 609
# Calculate SummaC Conv score for summary number 610
# Calculate SummaC Conv score for summary number 611
# Calculate SummaC Conv score for summary number 612
# Calculate SummaC Conv score for summary number 613
# Calculate SummaC Conv score for summary number 614
# Calculate SummaC Conv score for summary number 615
# Calculate SummaC Conv score for summary number 616
# Calculate SummaC Conv score for summary number 617
# Calculate SummaC Conv score for summary number 618
# Calculate SummaC Conv score for summary number 619
# Calculate SummaC Conv score for summary number 620
# Calculate SummaC Conv score for summary number 621
# Calculate SummaC Conv score for summary number 622
# Calculate SummaC Conv score for summary number 623
# Calculate SummaC Conv score for summary number 624
# Calculate SummaC Conv score for summary number 625
# Calculate SummaC Conv score for summary number 626
# Calculate SummaC Conv score for summary number 627
# Calculate SummaC Conv score for summary number 628
# Calculate SummaC Conv score for summary number 629
# Calculate SummaC Conv score for summary number 630
# Calculate SummaC Conv score for summary number 631
# Calculate SummaC Conv score for summary number 632
# Calculate SummaC Conv score for summary number 633
# Calculate SummaC Conv score for summary number 634
# Calculate SummaC Conv score for summary number 635
# Calculate SummaC Conv score for summary number 636
# Calculate SummaC Conv score for summary number 637
# Calculate SummaC Conv score for summary number 638
# Calculate SummaC Conv score for summary number 639
# Calculate SummaC Conv score for summary number 640
# Calculate SummaC Conv score for summary number 641
# Calculate SummaC Conv score for summary number 642
# Calculate SummaC Conv score for summary number 643
# Calculate SummaC Conv score for summary number 644
# Calculate SummaC Conv score for summary number 645
# Calculate SummaC Conv score for summary number 646
# Calculate SummaC Conv score for summary number 647
# Calculate SummaC Conv score for summary number 648
# Calculate SummaC Conv score for summary number 649
# Calculate SummaC Conv score for summary number 650
# Calculate SummaC Conv score for summary number 651
# Calculate SummaC Conv score for summary number 652
# Calculate SummaC Conv score for summary number 653
# Calculate SummaC Conv score for summary number 654
# Calculate SummaC Conv score for summary number 655
# Calculate SummaC Conv score for summary number 656
# Calculate SummaC Conv score for summary number 657
# Calculate SummaC Conv score for summary number 658
# Calculate SummaC Conv score for summary number 659
# Calculate SummaC Conv score for summary number 660
# Calculate SummaC Conv score for summary number 661
# Calculate SummaC Conv score for summary number 662
# Calculate SummaC Conv score for summary number 663
# Calculate SummaC Conv score for summary number 664
# Calculate SummaC Conv score for summary number 665
# Calculate SummaC Conv score for summary number 666
# Calculate SummaC Conv score for summary number 667
# Calculate SummaC Conv score for summary number 668
# Calculate SummaC Conv score for summary number 669
# Calculate SummaC Conv score for summary number 670
# Calculate SummaC Conv score for summary number 671
# Calculate SummaC Conv score for summary number 672
# Calculate SummaC Conv score for summary number 673
# Calculate SummaC Conv score for summary number 674
# Calculate SummaC Conv score for summary number 675
# Calculate SummaC Conv score for summary number 676
# Calculate SummaC Conv score for summary number 677
# Calculate SummaC Conv score for summary number 678
# Calculate SummaC Conv score for summary number 679
# Calculate SummaC Conv score for summary number 680
# Calculate SummaC Conv score for summary number 681
# Calculate SummaC Conv score for summary number 682
# Calculate SummaC Conv score for summary number 683
# Calculate SummaC Conv score for summary number 684
# Calculate SummaC Conv score for summary number 685
# Calculate SummaC Conv score for summary number 686
# Calculate SummaC Conv score for summary number 687
# Calculate SummaC Conv score for summary number 688
# Calculate SummaC Conv score for summary number 689
# Calculate SummaC Conv score for summary number 690
# Calculate SummaC Conv score for summary number 691
# Calculate SummaC Conv score for summary number 692
# Calculate SummaC Conv score for summary number 693
# Calculate SummaC Conv score for summary number 694
# Calculate SummaC Conv score for summary number 695
# Calculate SummaC Conv score for summary number 696
# Calculate SummaC Conv score for summary number 697
# Calculate SummaC Conv score for summary number 698
# Calculate SummaC Conv score for summary number 699
# Calculate SummaC Conv score for summary number 700
# Calculate SummaC Conv score for summary number 701
# Calculate SummaC Conv score for summary number 702
# Calculate SummaC Conv score for summary number 703
# Calculate SummaC Conv score for summary number 704
# Calculate SummaC Conv score for summary number 705
# Calculate SummaC Conv score for summary number 706
# Calculate SummaC Conv score for summary number 707
# Calculate SummaC Conv score for summary number 708
# Calculate SummaC Conv score for summary number 709
# Calculate SummaC Conv score for summary number 710
# Calculate SummaC Conv score for summary number 711
# Calculate SummaC Conv score for summary number 712
# Calculate SummaC Conv score for summary number 713
# Calculate SummaC Conv score for summary number 714
# Calculate SummaC Conv score for summary number 715
# Calculate SummaC Conv score for summary number 716
# Calculate SummaC Conv score for summary number 717
# Calculate SummaC Conv score for summary number 718
# Calculate SummaC Conv score for summary number 719
# Calculate SummaC Conv score for summary number 720
# Calculate SummaC Conv score for summary number 721
# Calculate SummaC Conv score for summary number 722
# Calculate SummaC Conv score for summary number 723
# Calculate SummaC Conv score for summary number 724
# Calculate SummaC Conv score for summary number 725
# Calculate SummaC Conv score for summary number 726
# Calculate SummaC Conv score for summary number 727
# Calculate SummaC Conv score for summary number 728
# Calculate SummaC Conv score for summary number 729
# Calculate SummaC Conv score for summary number 730
# Calculate SummaC Conv score for summary number 731
# Calculate SummaC Conv score for summary number 732
# Calculate SummaC Conv score for summary number 733
# Calculate SummaC Conv score for summary number 734
# Calculate SummaC Conv score for summary number 735
# Calculate SummaC Conv score for summary number 736
# Calculate SummaC Conv score for summary number 737
# Calculate SummaC Conv score for summary number 738
# Calculate SummaC Conv score for summary number 739
# Calculate SummaC Conv score for summary number 740
# Calculate SummaC Conv score for summary number 741
# Calculate SummaC Conv score for summary number 742
# Calculate SummaC Conv score for summary number 743
# Calculate SummaC Conv score for summary number 744
# Calculate SummaC Conv score for summary number 745
# Calculate SummaC Conv score for summary number 746
# Calculate SummaC Conv score for summary number 747
# Calculate SummaC Conv score for summary number 748
# Calculate SummaC Conv score for summary number 749
# Calculate SummaC Conv score for summary number 750
# Calculate SummaC Conv score for summary number 751
# Calculate SummaC Conv score for summary number 752
# Calculate SummaC Conv score for summary number 753
# Calculate SummaC Conv score for summary number 754
# Calculate SummaC Conv score for summary number 755
# Calculate SummaC Conv score for summary number 756
# Calculate SummaC Conv score for summary number 757
# Calculate SummaC Conv score for summary number 758
# Calculate SummaC Conv score for summary number 759
# Calculate SummaC Conv score for summary number 760
# Calculate SummaC Conv score for summary number 761
# Calculate SummaC Conv score for summary number 762
# Calculate SummaC Conv score for summary number 763
# Calculate SummaC Conv score for summary number 764
# Calculate SummaC Conv score for summary number 765
# Calculate SummaC Conv score for summary number 766
# Calculate SummaC Conv score for summary number 767
# Calculate SummaC Conv score for summary number 768
# Calculate SummaC Conv score for summary number 769
# Calculate SummaC Conv score for summary number 770
# Calculate SummaC Conv score for summary number 771
# Calculate SummaC Conv score for summary number 772
# Calculate SummaC Conv score for summary number 773
# Calculate SummaC Conv score for summary number 774
# Calculate SummaC Conv score for summary number 775
# Calculate SummaC Conv score for summary number 776
# Calculate SummaC Conv score for summary number 777
# Calculate SummaC Conv score for summary number 778
# Calculate SummaC Conv score for summary number 779
# Calculate SummaC Conv score for summary number 780
# Calculate SummaC Conv score for summary number 781
# Calculate SummaC Conv score for summary number 782
# Calculate SummaC Conv score for summary number 783
# Calculate SummaC Conv score for summary number 784
# Calculate SummaC Conv score for summary number 785
# Calculate SummaC Conv score for summary number 786
# Calculate SummaC Conv score for summary number 787
# Calculate SummaC Conv score for summary number 788
# Calculate SummaC Conv score for summary number 789
# Calculate SummaC Conv score for summary number 790
# Calculate SummaC Conv score for summary number 791
# Calculate SummaC Conv score for summary number 792
# Calculate SummaC Conv score for summary number 793
# Calculate SummaC Conv score for summary number 794
# Calculate SummaC Conv score for summary number 795
# Calculate SummaC Conv score for summary number 796
# Calculate SummaC Conv score for summary number 797
# Calculate SummaC Conv score for summary number 798
# Calculate SummaC Conv score for summary number 799
# Calculate SummaC Conv score for summary number 800
# Calculate SummaC Conv score for summary number 801
# Calculate SummaC Conv score for summary number 802
# Calculate SummaC Conv score for summary number 803
# Calculate SummaC Conv score for summary number 804
# Calculate SummaC Conv score for summary number 805
# Calculate SummaC Conv score for summary number 806
# Calculate SummaC Conv score for summary number 807
# Calculate SummaC Conv score for summary number 808
# Calculate SummaC Conv score for summary number 809
# Calculate SummaC Conv score for summary number 810
# Calculate SummaC Conv score for summary number 811
# Calculate SummaC Conv score for summary number 812
# Calculate SummaC Conv score for summary number 813
# Calculate SummaC Conv score for summary number 814
# Calculate SummaC Conv score for summary number 815
# Calculate SummaC Conv score for summary number 816
# Calculate SummaC Conv score for summary number 817
# Calculate SummaC Conv score for summary number 818
# Calculate SummaC Conv score for summary number 819
# Calculate SummaC Conv score for summary number 820
# Calculate SummaC Conv score for summary number 821
# Calculate SummaC Conv score for summary number 822
# Calculate SummaC Conv score for summary number 823
# Calculate SummaC Conv score for summary number 824
# Calculate SummaC Conv score for summary number 825
# Calculate SummaC Conv score for summary number 826
# Calculate SummaC Conv score for summary number 827
# Calculate SummaC Conv score for summary number 828
# Calculate SummaC Conv score for summary number 829
# Calculate SummaC Conv score for summary number 830
# Calculate SummaC Conv score for summary number 831
# Calculate SummaC Conv score for summary number 832
# Calculate SummaC Conv score for summary number 833
# Calculate SummaC Conv score for summary number 834
# Calculate SummaC Conv score for summary number 835
# Calculate SummaC Conv score for summary number 836
# Calculate SummaC Conv score for summary number 837
# Calculate SummaC Conv score for summary number 838
# Calculate SummaC Conv score for summary number 839
# Calculate SummaC Conv score for summary number 840
# Calculate SummaC Conv score for summary number 841
# Calculate SummaC Conv score for summary number 842
# Calculate SummaC Conv score for summary number 843
# Calculate SummaC Conv score for summary number 844
# Calculate SummaC Conv score for summary number 845
# Calculate SummaC Conv score for summary number 846
# Calculate SummaC Conv score for summary number 847
# Calculate SummaC Conv score for summary number 848
# Calculate SummaC Conv score for summary number 849
# Calculate SummaC Conv score for summary number 850
# Calculate SummaC Conv score for summary number 851
# Calculate SummaC Conv score for summary number 852
# Calculate SummaC Conv score for summary number 853
# Calculate SummaC Conv score for summary number 854
# Calculate SummaC Conv score for summary number 855
# Calculate SummaC Conv score for summary number 856
# Calculate SummaC Conv score for summary number 857
# Calculate SummaC Conv score for summary number 858
# Calculate SummaC Conv score for summary number 859
# Calculate SummaC Conv score for summary number 860
# Calculate SummaC Conv score for summary number 861
# Calculate SummaC Conv score for summary number 862
# Calculate SummaC Conv score for summary number 863
# Calculate SummaC Conv score for summary number 864
# Calculate SummaC Conv score for summary number 865
# Calculate SummaC Conv score for summary number 866
# Calculate SummaC Conv score for summary number 867
# Calculate SummaC Conv score for summary number 868
# Calculate SummaC Conv score for summary number 869
# Calculate SummaC Conv score for summary number 870
# Calculate SummaC Conv score for summary number 871
# Calculate SummaC Conv score for summary number 872
# Calculate SummaC Conv score for summary number 873
# Calculate SummaC Conv score for summary number 874
# Calculate SummaC Conv score for summary number 875
# Calculate SummaC Conv score for summary number 876
# Calculate SummaC Conv score for summary number 877
# Calculate SummaC Conv score for summary number 878
# Calculate SummaC Conv score for summary number 879
# Calculate SummaC Conv score for summary number 880
# Calculate SummaC Conv score for summary number 881
# Calculate SummaC Conv score for summary number 882
# Calculate SummaC Conv score for summary number 883
# Calculate SummaC Conv score for summary number 884
# Calculate SummaC Conv score for summary number 885
# Calculate SummaC Conv score for summary number 886
# Calculate SummaC Conv score for summary number 887
# Calculate SummaC Conv score for summary number 888
# Calculate SummaC Conv score for summary number 889
# Calculate SummaC Conv score for summary number 890
# Calculate SummaC Conv score for summary number 891
# Calculate SummaC Conv score for summary number 892
# Calculate SummaC Conv score for summary number 893
# Calculate SummaC Conv score for summary number 894
# Calculate SummaC Conv score for summary number 895
# Calculate SummaC Conv score for summary number 896
# Calculate SummaC Conv score for summary number 897
# Calculate SummaC Conv score for summary number 898
# Calculate SummaC Conv score for summary number 899
# Calculate SummaC Conv score for summary number 900
# Calculate SummaC Conv score for summary number 901
# Calculate SummaC Conv score for summary number 902
# Calculate SummaC Conv score for summary number 903
# Calculate SummaC Conv score for summary number 904
# Calculate SummaC Conv score for summary number 905
# Calculate SummaC Conv score for summary number 906
# Calculate SummaC Conv score for summary number 907
# Calculate SummaC Conv score for summary number 908
# Calculate SummaC Conv score for summary number 909
# Calculate SummaC Conv score for summary number 910
# Calculate SummaC Conv score for summary number 911
# Calculate SummaC Conv score for summary number 912
# Calculate SummaC Conv score for summary number 913
# Calculate SummaC Conv score for summary number 914
# Calculate SummaC Conv score for summary number 915
# Calculate SummaC Conv score for summary number 916
# Calculate SummaC Conv score for summary number 917
# Calculate SummaC Conv score for summary number 918
# Calculate SummaC Conv score for summary number 919
# Calculate SummaC Conv score for summary number 920
# Calculate SummaC Conv score for summary number 921
# Calculate SummaC Conv score for summary number 922
# Calculate SummaC Conv score for summary number 923
# Calculate SummaC Conv score for summary number 924
# Calculate SummaC Conv score for summary number 925
# Calculate SummaC Conv score for summary number 926
# Calculate SummaC Conv score for summary number 927
# Calculate SummaC Conv score for summary number 928
# Calculate SummaC Conv score for summary number 929
# Calculate SummaC Conv score for summary number 930
# Calculate SummaC Conv score for summary number 931
# Calculate SummaC Conv score for summary number 932
# Calculate SummaC Conv score for summary number 933
# Calculate SummaC Conv score for summary number 934
# Calculate SummaC Conv score for summary number 935
# Calculate SummaC Conv score for summary number 936
# Calculate SummaC Conv score for summary number 937
# Calculate SummaC Conv score for summary number 938
# Calculate SummaC Conv score for summary number 939
# Calculate SummaC Conv score for summary number 940
# Calculate SummaC Conv score for summary number 941
# Calculate SummaC Conv score for summary number 942
# Calculate SummaC Conv score for summary number 943
# ...
# Calculate SummaC Conv score for summary number 3246
# Calculate SummaC Conv score for summary number 3247
# Calculate SummaC Conv score for summary number 3248
# Calculate SummaC Conv score for summary number 3249
# Calculate SummaC Conv score for summary number 3250
# Calculate SummaC Conv score for summary number 3251
# Calculate SummaC Conv score for summary number 3252
# Calculate SummaC Conv score for summary number 3253
# Calculate SummaC Conv score for summary number 3254
# Calculate SummaC Conv score for summary number 3255
# Calculate SummaC Conv score for summary number 3256
# Calculate SummaC Conv score for summary number 3257
# Calculate SummaC Conv score for summary number 3258
# Calculate SummaC Conv score for summary number 3259
# Calculate SummaC Conv score for summary number 3260
# Calculate SummaC Conv score for summary number 3261
# Calculate SummaC Conv score for summary number 3262
# Calculate SummaC Conv score for summary number 3263
# Calculate SummaC Conv score for summary number 3264
# Calculate SummaC Conv score for summary number 3265
# Calculate SummaC Conv score for summary number 3266
# Calculate SummaC Conv score for summary number 3267
# Calculate SummaC Conv score for summary number 3268
# Calculate SummaC Conv score for summary number 3269
# Calculate SummaC Conv score for summary number 3270
# Calculate SummaC Conv score for summary number 3271
# Calculate SummaC Conv score for summary number 3272
# Calculate SummaC Conv score for summary number 3273
# Calculate SummaC Conv score for summary number 3274
# Calculate SummaC Conv score for summary number 3275
# Calculate SummaC Conv score for summary number 3276
# Calculate SummaC Conv score for summary number 3277
# Calculate SummaC Conv score for summary number 3278
# Calculate SummaC Conv score for summary number 3279
# Calculate SummaC Conv score for summary number 3280
# Calculate SummaC Conv score for summary number 3281
# Calculate SummaC Conv score for summary number 3282
# Calculate SummaC Conv score for summary number 3283
# Calculate SummaC Conv score for summary number 3284
# Calculate SummaC Conv score for summary number 3285
# Calculate SummaC Conv score for summary number 3286
# Calculate SummaC Conv score for summary number 3287
# Calculate SummaC Conv score for summary number 3288
# Calculate SummaC Conv score for summary number 3289
# Calculate SummaC Conv score for summary number 3290
# Calculate SummaC Conv score for summary number 3291
# Calculate SummaC Conv score for summary number 3292
# Calculate SummaC Conv score for summary number 3293
# Calculate SummaC Conv score for summary number 3294
# Calculate SummaC Conv score for summary number 3295
# Calculate SummaC Conv score for summary number 3296
# Calculate SummaC Conv score for summary number 3297
# Calculate SummaC Conv score for summary number 3298
# Calculate SummaC Conv score for summary number 3299
# Calculate SummaC Conv score for summary number 3300
# Calculate SummaC Conv score for summary number 3301
# Calculate SummaC Conv score for summary number 3302
# Calculate SummaC Conv score for summary number 3303
# Calculate SummaC Conv score for summary number 3304
# Calculate SummaC Conv score for summary number 3305
# Calculate SummaC Conv score for summary number 3306
# Calculate SummaC Conv score for summary number 3307
# Calculate SummaC Conv score for summary number 3308
# Calculate SummaC Conv score for summary number 3309
# Calculate SummaC Conv score for summary number 3310
# Calculate SummaC Conv score for summary number 3311
# Calculate SummaC Conv score for summary number 3312
# Calculate SummaC Conv score for summary number 3313
# Calculate SummaC Conv score for summary number 3314
# Calculate SummaC Conv score for summary number 3315
# Calculate SummaC Conv score for summary number 3316
# Calculate SummaC Conv score for summary number 3317
# Calculate SummaC Conv score for summary number 3318
# Calculate SummaC Conv score for summary number 3319
# Calculate SummaC Conv score for summary number 3320
# Calculate SummaC Conv score for summary number 3321
# Calculate SummaC Conv score for summary number 3322
# Calculate SummaC Conv score for summary number 3323
# Calculate SummaC Conv score for summary number 3324
# Calculate SummaC Conv score for summary number 3325
# Calculate SummaC Conv score for summary number 3326
# Calculate SummaC Conv score for summary number 3327
# Calculate SummaC Conv score for summary number 3328
# Calculate SummaC Conv score for summary number 3329
# Calculate SummaC Conv score for summary number 3330
# Calculate SummaC Conv score for summary number 3331
# Calculate SummaC Conv score for summary number 3332
# Calculate SummaC Conv score for summary number 3333
# Calculate SummaC Conv score for summary number 3334
# Calculate SummaC Conv score for summary number 3335
# Calculate SummaC Conv score for summary number 3336
# Calculate SummaC Conv score for summary number 3337
# Calculate SummaC Conv score for summary number 3338
# Calculate SummaC Conv score for summary number 3339
# Calculate SummaC Conv score for summary number 3340
# Calculate SummaC Conv score for summary number 3341
# Calculate SummaC Conv score for summary number 3342
# Calculate SummaC Conv score for summary number 3343
# Calculate SummaC Conv score for summary number 3344
# Calculate SummaC Conv score for summary number 3345
# Calculate SummaC Conv score for summary number 3346
# Calculate SummaC Conv score for summary number 3347
# Calculate SummaC Conv score for summary number 3348
# Calculate SummaC Conv score for summary number 3349
# Calculate SummaC Conv score for summary number 3350
# Calculate SummaC Conv score for summary number 3351
# Calculate SummaC Conv score for summary number 3352
# Calculate SummaC Conv score for summary number 3353
# Calculate SummaC Conv score for summary number 3354
# Calculate SummaC Conv score for summary number 3355
# Calculate SummaC Conv score for summary number 3356
# Calculate SummaC Conv score for summary number 3357
# Calculate SummaC Conv score for summary number 3358
# Calculate SummaC Conv score for summary number 3359
# Calculate SummaC Conv score for summary number 3360
# Calculate SummaC Conv score for summary number 3361
# Calculate SummaC Conv score for summary number 3362
# Calculate SummaC Conv score for summary number 3363
# Calculate SummaC Conv score for summary number 3364
# Calculate SummaC Conv score for summary number 3365
# Calculate SummaC Conv score for summary number 3366
# Calculate SummaC Conv score for summary number 3367
# Calculate SummaC Conv score for summary number 3368
# Calculate SummaC Conv score for summary number 3369
# Calculate SummaC Conv score for summary number 3370
# Calculate SummaC Conv score for summary number 3371
# Calculate SummaC Conv score for summary number 3372
# Calculate SummaC Conv score for summary number 3373
# Calculate SummaC Conv score for summary number 3374
# Calculate SummaC Conv score for summary number 3375
# Calculate SummaC Conv score for summary number 3376
# Calculate SummaC Conv score for summary number 3377
# Calculate SummaC Conv score for summary number 3378
# Calculate SummaC Conv score for summary number 3379
# Calculate SummaC Conv score for summary number 3380
# Calculate SummaC Conv score for summary number 3381
# Calculate SummaC Conv score for summary number 3382
# Calculate SummaC Conv score for summary number 3383
# Calculate SummaC Conv score for summary number 3384
# Calculate SummaC Conv score for summary number 3385
# Calculate SummaC Conv score for summary number 3386
# Calculate SummaC Conv score for summary number 3387
# Calculate SummaC Conv score for summary number 3388
# Calculate SummaC Conv score for summary number 3389
# Calculate SummaC Conv score for summary number 3390
# Calculate SummaC Conv score for summary number 3391
# Calculate SummaC Conv score for summary number 3392
# Calculate SummaC Conv score for summary number 3393
# Calculate SummaC Conv score for summary number 3394
# Calculate SummaC Conv score for summary number 3395
# Calculate SummaC Conv score for summary number 3396
# Calculate SummaC Conv score for summary number 3397
# Calculate SummaC Conv score for summary number 3398
# Calculate SummaC Conv score for summary number 3399
# Calculate SummaC Conv score for summary number 3400
# Calculate SummaC Conv score for summary number 3401
# Calculate SummaC Conv score for summary number 3402
# Calculate SummaC Conv score for summary number 3403
# Calculate SummaC Conv score for summary number 3404
# Calculate SummaC Conv score for summary number 3405
# Calculate SummaC Conv score for summary number 3406
# Calculate SummaC Conv score for summary number 3407
# Calculate SummaC Conv score for summary number 3408
# Calculate SummaC Conv score for summary number 3409
# Calculate SummaC Conv score for summary number 3410
# Calculate SummaC Conv score for summary number 3411
# Calculate SummaC Conv score for summary number 3412
# Calculate SummaC Conv score for summary number 3413
# Calculate SummaC Conv score for summary number 3414
# Calculate SummaC Conv score for summary number 3415
# Calculate SummaC Conv score for summary number 3416
# Calculate SummaC Conv score for summary number 3417
# Calculate SummaC Conv score for summary number 3418
# Calculate SummaC Conv score for summary number 3419
# Calculate SummaC Conv score for summary number 3420
# Calculate SummaC Conv score for summary number 3421
# Calculate SummaC Conv score for summary number 3422
# Calculate SummaC Conv score for summary number 3423
# Calculate SummaC Conv score for summary number 3424
# Calculate SummaC Conv score for summary number 3425
# Calculate SummaC Conv score for summary number 3426
# Calculate SummaC Conv score for summary number 3427
# Calculate SummaC Conv score for summary number 3428
# Calculate SummaC Conv score for summary number 3429
# Calculate SummaC Conv score for summary number 3430
# Calculate SummaC Conv score for summary number 3431
# Calculate SummaC Conv score for summary number 3432
# Calculate SummaC Conv score for summary number 3433
# Calculate SummaC Conv score for summary number 3434
# Calculate SummaC Conv score for summary number 3435
# Calculate SummaC Conv score for summary number 3436
# Calculate SummaC Conv score for summary number 3437
# Calculate SummaC Conv score for summary number 3438
# Calculate SummaC Conv score for summary number 3439
# Calculate SummaC Conv score for summary number 3440
# Calculate SummaC Conv score for summary number 3441
# Calculate SummaC Conv score for summary number 3442
# Calculate SummaC Conv score for summary number 3443
# Calculate SummaC Conv score for summary number 3444
# Calculate SummaC Conv score for summary number 3445
# Calculate SummaC Conv score for summary number 3446
# Calculate SummaC Conv score for summary number 3447
# Calculate SummaC Conv score for summary number 3448
# Calculate SummaC Conv score for summary number 3449
# Calculate SummaC Conv score for summary number 3450
# Calculate SummaC Conv score for summary number 3451
# Calculate SummaC Conv score for summary number 3452
# Calculate SummaC Conv score for summary number 3453
# Calculate SummaC Conv score for summary number 3454
# Calculate SummaC Conv score for summary number 3455
# Calculate SummaC Conv score for summary number 3456
# Calculate SummaC Conv score for summary number 3457
# Calculate SummaC Conv score for summary number 3458
# Calculate SummaC Conv score for summary number 3459
# Calculate SummaC Conv score for summary number 3460
# Calculate SummaC Conv score for summary number 3461
# Calculate SummaC Conv score for summary number 3462
# Calculate SummaC Conv score for summary number 3463
# Calculate SummaC Conv score for summary number 3464
# Calculate SummaC Conv score for summary number 3465
# Calculate SummaC Conv score for summary number 3466
# Calculate SummaC Conv score for summary number 3467
# Calculate SummaC Conv score for summary number 3468
# Calculate SummaC Conv score for summary number 3469
# Calculate SummaC Conv score for summary number 3470
# Calculate SummaC Conv score for summary number 3471
# Calculate SummaC Conv score for summary number 3472
# Calculate SummaC Conv score for summary number 3473
# Calculate SummaC Conv score for summary number 3474
# Calculate SummaC Conv score for summary number 3475
# Calculate SummaC Conv score for summary number 3476
# Calculate SummaC Conv score for summary number 3477
# Calculate SummaC Conv score for summary number 3478
# Calculate SummaC Conv score for summary number 3479
# Calculate SummaC Conv score for summary number 3480
# Calculate SummaC Conv score for summary number 3481
# Calculate SummaC Conv score for summary number 3482
# Calculate SummaC Conv score for summary number 3483
# Calculate SummaC Conv score for summary number 3484
# Calculate SummaC Conv score for summary number 3485
# Calculate SummaC Conv score for summary number 3486
# Calculate SummaC Conv score for summary number 3487
# Calculate SummaC Conv score for summary number 3488
# Calculate SummaC Conv score for summary number 3489
# Calculate SummaC Conv score for summary number 3490
# Calculate SummaC Conv score for summary number 3491
# Calculate SummaC Conv score for summary number 3492
# Calculate SummaC Conv score for summary number 3493
# Calculate SummaC Conv score for summary number 3494
# Calculate SummaC Conv score for summary number 3495
# Calculate SummaC Conv score for summary number 3496
# Calculate SummaC Conv score for summary number 3497
# Calculate SummaC Conv score for summary number 3498
# Calculate SummaC Conv score for summary number 3499
# Calculate SummaC Conv score for summary number 3500
# Calculate SummaC Conv score for summary number 3501
# Calculate SummaC Conv score for summary number 3502
# Calculate SummaC Conv score for summary number 3503
# Calculate SummaC Conv score for summary number 3504
# Calculate SummaC Conv score for summary number 3505
# Calculate SummaC Conv score for summary number 3506
# Calculate SummaC Conv score for summary number 3507
# Calculate SummaC Conv score for summary number 3508
# Calculate SummaC Conv score for summary number 3509
# Calculate SummaC Conv score for summary number 3510
# Calculate SummaC Conv score for summary number 3511
# Calculate SummaC Conv score for summary number 3512
# Calculate SummaC Conv score for summary number 3513
# Calculate SummaC Conv score for summary number 3514
# Calculate SummaC Conv score for summary number 3515
# Calculate SummaC Conv score for summary number 3516
# Calculate SummaC Conv score for summary number 3517
# Calculate SummaC Conv score for summary number 3518
# Calculate SummaC Conv score for summary number 3519
# Calculate SummaC Conv score for summary number 3520
# Calculate SummaC Conv score for summary number 3521
# Calculate SummaC Conv score for summary number 3522
# Calculate SummaC Conv score for summary number 3523
# Calculate SummaC Conv score for summary number 3524
# Calculate SummaC Conv score for summary number 3525
# Calculate SummaC Conv score for summary number 3526
# Calculate SummaC Conv score for summary number 3527
# Calculate SummaC Conv score for summary number 3528
# Calculate SummaC Conv score for summary number 3529
# Calculate SummaC Conv score for summary number 3530
# Calculate SummaC Conv score for summary number 3531
# Calculate SummaC Conv score for summary number 3532
# Calculate SummaC Conv score for summary number 3533
# Calculate SummaC Conv score for summary number 3534
# Calculate SummaC Conv score for summary number 3535
# Calculate SummaC Conv score for summary number 3536
# Calculate SummaC Conv score for summary number 3537
# Calculate SummaC Conv score for summary number 3538
# Calculate SummaC Conv score for summary number 3539
# Calculate SummaC Conv score for summary number 3540
# Calculate SummaC Conv score for summary number 3541
# Calculate SummaC Conv score for summary number 3542
# Calculate SummaC Conv score for summary number 3543
# Calculate SummaC Conv score for summary number 3544
# Calculate SummaC Conv score for summary number 3545
# Calculate SummaC Conv score for summary number 3546
# Calculate SummaC Conv score for summary number 3547
# Calculate SummaC Conv score for summary number 3548
# Calculate SummaC Conv score for summary number 3549
# Calculate SummaC Conv score for summary number 3550
# Calculate SummaC Conv score for summary number 3551
# Calculate SummaC Conv score for summary number 3552

# %%
print(f"Average Score: {average_score}")
# Out:
# Average Score: 0.39181168452912085

# %%
model_names = ["llama_prompt_sum_llama_holdings", "legalBertLarge_sum_llama_holdings", "legalBertLarge_sum_Mistal_holdings", "legalBertLarge_sum_Mistal_holdings_without_hint", "legalBertLarge_sum_llama_holdings_without_hint"]

# %%
import pandas as pd

# This code is the same as above, but it reads file names in a loop to score multiple results files from gdrive.
for model_name in model_names:
  df = pd.read_csv(f"/content/drive/MyDrive/Lang Gen Project/Formatted Holding Predictions for SummaC and Bleurt /{model_name}_predictions.csv")

  documents = df['Input'].tolist()
  summaries = df['Prediction'].tolist()

  if len(documents) != len(summaries):
          raise ValueError("The lengths of the documents and summaries lists do not match.")

  total_score = 0
  scores = []
  num = 0

  for document, summary in zip(documents, summaries):
    print(f"Calculate SummaC Conv score for summary number {num+1}")
    num += 1
    if pd.isna(summary):
      summary = "Null"
    score = model_conv.score([document], [summary])
    {'Document': document, 'Summary': summary, 'Score': score}
    scores.append({'Document': document, 'Summary': summary, 'Score': score['scores'][0]})
    total_score += score['scores'][0]

  results_df = pd.DataFrame(scores)
  results_df.to_csv(f'/content/drive/MyDrive/Lang Gen Project/Metrics/{model_name}_summac_results.csv', index=False)
  # Calculate and write average score
  average_score = total_score / len(scores)
  with open(f'/content/drive/MyDrive/Lang Gen Project/Metrics/{model_name}_average_summac.txt', 'w') as file:
      file.write(f"Average Score: {average_score}\n")
# Out:
# Calculate SummaC Conv score for summary number 1
# Calculate SummaC Conv score for summary number 2
# Calculate SummaC Conv score for summary number 3
# Calculate SummaC Conv score for summary number 4
# Calculate SummaC Conv score for summary number 5
# Calculate SummaC Conv score for summary number 6
# Calculate SummaC Conv score for summary number 7
# Calculate SummaC Conv score for summary number 8
# Calculate SummaC Conv score for summary number 9
# Calculate SummaC Conv score for summary number 10
# Calculate SummaC Conv score for summary number 11
# Calculate SummaC Conv score for summary number 12
# Calculate SummaC Conv score for summary number 13
# Calculate SummaC Conv score for summary number 14
# Calculate SummaC Conv score for summary number 15
# Calculate SummaC Conv score for summary number 1
# Calculate SummaC Conv score for summary number 2
# Calculate SummaC Conv score for summary number 3
# Calculate SummaC Conv score for summary number 4
# Calculate SummaC Conv score for summary number 5
# Calculate SummaC Conv score for summary number 6
# Calculate SummaC Conv score for summary number 7
# Calculate SummaC Conv score for summary number 8
# Calculate SummaC Conv score for summary number 9
# Calculate SummaC Conv score for summary number 10
# Calculate SummaC Conv score for summary number 11
# Calculate SummaC Conv score for summary number 12
# Calculate SummaC Conv score for summary number 13
# Calculate SummaC Conv score for summary number 14
# Calculate SummaC Conv score for summary number 15
# Calculate SummaC Conv score for summary number 1
# Calculate SummaC Conv score for summary number 2
# Calculate SummaC Conv score for summary number 3
# Calculate SummaC Conv score for summary number 4
# Calculate SummaC Conv score for summary number 5
# Calculate SummaC Conv score for summary number 6
# Calculate SummaC Conv score for summary number 7
# Calculate SummaC Conv score for summary number 8
# Calculate SummaC Conv score for summary number 9
# Calculate SummaC Conv score for summary number 10
# Calculate SummaC Conv score for summary number 11
# Calculate SummaC Conv score for summary number 12
# Calculate SummaC Conv score for summary number 13
# Calculate SummaC Conv score for summary number 14
# Calculate SummaC Conv score for summary number 15
# Calculate SummaC Conv score for summary number 1
# Calculate SummaC Conv score for summary number 2
# Calculate SummaC Conv score for summary number 3
# Calculate SummaC Conv score for summary number 4
# Calculate SummaC Conv score for summary number 5
# Calculate SummaC Conv score for summary number 6
# Calculate SummaC Conv score for summary number 7
# Calculate SummaC Conv score for summary number 8
# Calculate SummaC Conv score for summary number 9
# Calculate SummaC Conv score for summary number 10
# Calculate SummaC Conv score for summary number 11
# Calculate SummaC Conv score for summary number 12
# Calculate SummaC Conv score for summary number 13
# Calculate SummaC Conv score for summary number 14
# Calculate SummaC Conv score for summary number 15
# Calculate SummaC Conv score for summary number 1
# Calculate SummaC Conv score for summary number 2
# Calculate SummaC Conv score for summary number 3
# Calculate SummaC Conv score for summary number 4
# Calculate SummaC Conv score for summary number 5
# Calculate SummaC Conv score for summary number 6
# Calculate SummaC Conv score for summary number 7
# Calculate SummaC Conv score for summary number 8
# Calculate SummaC Conv score for summary number 9
# Calculate SummaC Conv score for summary number 10
# Calculate SummaC Conv score for summary number 11
# Calculate SummaC Conv score for summary number 12
# Calculate SummaC Conv score for summary number 13
# Calculate SummaC Conv score for summary number 14
# Calculate SummaC Conv score for summary number 15

# %% [markdown]
# This is actually separate data cleaning that I used to assemble the Likert scores

# %%
file_path_test = '/content/drive/MyDrive/Lang Gen Project/qlora_data/cleaned_test_qlora.jsonl'

# %%
test_df = pd.read_json(file_path_test, lines=True)

# %%
pred_files = ["mistral", "llama2", "longformer", "T5"]

# %%
likert_df = pd.DataFrame(columns=["input", "reference", "mistral", "mistral_likert", "llama2", "llama2_likert", "longformer", "longformer_likert", "T5", "T5_likert"])

for i in range(10):
  input_txt = test_df.iloc[i]['input']
  reference_txt = test_df.iloc[i]['output']
  temp_df = pd.DataFrame({'input': [input_txt],'reference': [reference_txt]})

  likert_df = pd.concat([likert_df, temp_df], ignore_index=True)

for model in pred_files:
  model_df = pd.read_csv(f"/content/drive/MyDrive/Lang Gen Project/Results/{model}_predictions.csv")

  for i in range(10):
    pred = model_df.iloc[i]['Prediction']
    likert_df.at[i, model] = pred

# %%
likert_df.iloc[0]
# Out:
# input                Defendant’s attorney then told the jury that L...
# reference            holding that a good faith belief that a firear...
# mistral               Holding: Defendant could not claim the gun wa...
# mistral_likert                                                     NaN
# llama2                 holding that the gun in question was still a...
# llama2_likert                                                      NaN
# longformer           holding that the district court properly exclu...
# longformer_likert                                                  NaN
# T5                   holding that the government must prove that th...
# T5_likert                                                          NaN
# Name: 0, dtype: object

# %%
likert_df.to_csv(f'/content/drive/MyDrive/Lang Gen Project/Metrics/parenthetical_likert.csv', index=False)
